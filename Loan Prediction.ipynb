# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('Loan Prediction Train.csv')

# %%
dataset1 = pd.read_csv('Loan Prediction Test.csv')

# %%
dataset.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
dataset1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
dataset = dataset.dropna(subset=['Gender'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 601 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              601 non-null object
# Gender               601 non-null object
# Married              598 non-null object
# Dependents           586 non-null object
# Education            601 non-null object
# Self_Employed        569 non-null object
# ApplicantIncome      601 non-null int64
# CoapplicantIncome    601 non-null float64
# LoanAmount           579 non-null float64
# Loan_Amount_Term     587 non-null float64
# Credit_History       552 non-null float64
# Property_Area        601 non-null object
# Loan_Status          601 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 65.7+ KB

# %%
dataset['Married'] = dataset['Married'].fillna('Yes')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 601 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              601 non-null object
# Gender               601 non-null object
# Married              601 non-null object
# Dependents           586 non-null object
# Education            601 non-null object
# Self_Employed        569 non-null object
# ApplicantIncome      601 non-null int64
# CoapplicantIncome    601 non-null float64
# LoanAmount           579 non-null float64
# Loan_Amount_Term     587 non-null float64
# Credit_History       552 non-null float64
# Property_Area        601 non-null object
# Loan_Status          601 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 65.7+ KB

# %%
dataset = dataset.dropna(subset=['LoanAmount'])

# %%
dataset = dataset.dropna(subset=['Self_Employed'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 548 entries, 1 to 613
# Data columns (total 13 columns):
# Loan_ID              548 non-null object
# Gender               548 non-null object
# Married              548 non-null object
# Dependents           535 non-null object
# Education            548 non-null object
# Self_Employed        548 non-null object
# ApplicantIncome      548 non-null int64
# CoapplicantIncome    548 non-null float64
# LoanAmount           548 non-null float64
# Loan_Amount_Term     535 non-null float64
# Credit_History       505 non-null float64
# Property_Area        548 non-null object
# Loan_Status          548 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 59.9+ KB

# %%
dataset = dataset.dropna(subset=['Credit_History'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 505 entries, 1 to 613
# Data columns (total 13 columns):
# Loan_ID              505 non-null object
# Gender               505 non-null object
# Married              505 non-null object
# Dependents           492 non-null object
# Education            505 non-null object
# Self_Employed        505 non-null object
# ApplicantIncome      505 non-null int64
# CoapplicantIncome    505 non-null float64
# LoanAmount           505 non-null float64
# Loan_Amount_Term     492 non-null float64
# Credit_History       505 non-null float64
# Property_Area        505 non-null object
# Loan_Status          505 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 55.2+ KB

# %%
dataset = dataset.dropna(subset=['Dependents'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 1 to 613
# Data columns (total 13 columns):
# Loan_ID              492 non-null object
# Gender               492 non-null object
# Married              492 non-null object
# Dependents           492 non-null object
# Education            492 non-null object
# Self_Employed        492 non-null object
# ApplicantIncome      492 non-null int64
# CoapplicantIncome    492 non-null float64
# LoanAmount           492 non-null float64
# Loan_Amount_Term     480 non-null float64
# Credit_History       492 non-null float64
# Property_Area        492 non-null object
# Loan_Status          492 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 53.8+ KB

# %%
dataset = dataset.dropna(subset=['Loan_Amount_Term'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 13 columns):
# Loan_ID              480 non-null object
# Gender               480 non-null object
# Married              480 non-null object
# Dependents           480 non-null object
# Education            480 non-null object
# Self_Employed        480 non-null object
# ApplicantIncome      480 non-null int64
# CoapplicantIncome    480 non-null float64
# LoanAmount           480 non-null float64
# Loan_Amount_Term     480 non-null float64
# Credit_History       480 non-null float64
# Property_Area        480 non-null object
# Loan_Status          480 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.5+ KB

# %%
dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        1581.093583  144.735417        342.050000
# std        5668.251251        2617.692267   80.508164         65.212401
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5852.500000        2253.250000  170.000000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_History
# count      480.000000
# mean         0.854167
# std          0.353307
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
dataset['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dataset['Loan_Status'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
dataset.head(40)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 12  LP001028    Male     Yes          2      Graduate            No
# 13  LP001029    Male      No          0      Graduate            No
# 14  LP001030    Male     Yes          2      Graduate            No
# ...

# %%
dataset.loc[dataset['Gender'] == 'Male','Gender'] = 0
dataset.loc[dataset['Gender'] == 'Female','Gender'] = 1

# %%
dataset.loc[dataset['Loan_Status'] == 'Y','Loan_Status'] = 1
dataset.loc[dataset['Loan_Status'] == 'N','Loan_Status'] = 0

# %%
g = sns.FacetGrid(dataset,col='Loan_Status')
g.map(plt.hist,'Gender',bins=10)
plt.show()

# %%
dataset.loc[dataset['Dependents'] == '3+','Dependents'] = 4

# %%
dataset['Dependents'] = dataset['Dependents'].astype(int)

# %%
dataset.loc[((dataset['Married'] == 'Yes') & (dataset['Dependents'] == 0)),'Marital'] = 1
dataset.loc[((dataset['Married'] == 'Yes') & (dataset['Dependents'] == 1)),'Marital'] = 2
dataset.loc[((dataset['Married'] == 'Yes') & (dataset['Dependents'] == 2)),'Marital'] = 3
dataset.loc[((dataset['Married'] == 'Yes') & (dataset['Dependents'] > 2)),'Marital'] = 4

dataset.loc[dataset['Married'] == 'No','Marital'] = 0

# %%
g = sns.FacetGrid(dataset,col='Loan_Status')
g.map(plt.hist,'Marital',bins=10)
plt.show()

# %%
#dataset.loc[dataset['Dependents'] == '3+','Dependents'] = 4

# %%
#dataset['Dependents'] = dataset['Dependents'].astype(int)

# %%
g = sns.FacetGrid(dataset,col='Loan_Status')
g.map(plt.hist,'Dependents',bins=10)
plt.show()

# %%
dataset.loc[dataset['Education'] == 'Graduate','Education'] = 1
dataset.loc[dataset['Education'] == 'Not Graduate','Education'] = 0

# %%
g = sns.FacetGrid(dataset,col='Loan_Status')
g.map(plt.hist,'Education',bins=10)
plt.show()

# %%
dataset.loc[dataset['Self_Employed'] == 'Yes','Self_Employed'] = 1
dataset.loc[dataset['Self_Employed'] == 'No','Self_Employed'] = 0

# %%
g = sns.FacetGrid(dataset,col='Loan_Status')
g.map(plt.hist,'Self_Employed',bins=10)
plt.show()

# %%
dataset['Income'] = dataset['ApplicantIncome'] + dataset['CoapplicantIncome']

# %%
dataset.head()
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 1  LP001003      0     Yes           1         1             0
# 2  LP001005      0     Yes           0         1             1
# 3  LP001006      0     Yes           0         0             0
# 4  LP001008      0      No           0         1             0
# 5  LP001011      0     Yes           2         1             1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status  Marital  Income
# 1             1.0         Rural           0      2.0  6091.0
# ...

# %%
dataset['Income'] = dataset['Income'].astype(int)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 15 columns):
# Loan_ID              480 non-null object
# Gender               480 non-null object
# Married              480 non-null object
# Dependents           480 non-null int32
# Education            480 non-null object
# Self_Employed        480 non-null object
# ApplicantIncome      480 non-null int64
# CoapplicantIncome    480 non-null float64
# LoanAmount           480 non-null float64
# Loan_Amount_Term     480 non-null float64
# Credit_History       480 non-null float64
# Property_Area        480 non-null object
# Loan_Status          480 non-null object
# Marital              480 non-null float64
# Income               480 non-null int32
# dtypes: float64(5), int32(2), int64(1), object(7)
# memory usage: 76.2+ KB

# %%
dataset.loc[((dataset['Income']>0) & (dataset['Income'] < 5000)),'Income'] = 0
dataset.loc[((dataset['Income']>=5000) & (dataset['Income'] < 10000)),'Income'] = 1
dataset.loc[((dataset['Income']>=10000) & (dataset['Income'] < 15000)),'Income'] = 2
dataset.loc[((dataset['Income']>=15000) & (dataset['Income'] < 20000)),'Income'] = 3
dataset.loc[(dataset['Income']>=20000),'Income'] = 4

# %%
g = sns.FacetGrid(dataset,col='Loan_Status')
g.map(plt.hist,'Income',bins=10)
plt.show()

# %%
dataset.loc[dataset['Property_Area'] == 'Urban','Property_Area'] = 1
dataset.loc[dataset['Property_Area'] == 'Rural','Property_Area'] = 3
dataset.loc[dataset['Property_Area'] == 'Semiurban','Property_Area'] = 2

# %%
g = sns.FacetGrid(dataset,col='Loan_Status')
g.map(plt.hist,'Property_Area',bins=10)
plt.show()

# %%
dataset.loc[((dataset['Property_Area'] == 1) & (dataset['Education'] == 0)),'Area'] = 1

# %%
dataset.head()
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 1  LP001003      0     Yes           1         1             0
# 2  LP001005      0     Yes           0         1             1
# 3  LP001006      0     Yes           0         0             0
# 4  LP001008      0      No           0         1             0
# 5  LP001011      0     Yes           2         1             1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status  Marital  Income  Area
# 1             1.0             3           0      2.0       1   NaN
# ...

# %%
dataset.loc[((dataset['Property_Area'] == 1) & (dataset['Education'] == 1)),'Area'] = 2
dataset.loc[((dataset['Property_Area'] == 2) & (dataset['Education'] == 0)),'Area'] = 3
dataset.loc[((dataset['Property_Area'] == 2) & (dataset['Education'] == 1)),'Area'] = 4
dataset.loc[((dataset['Property_Area'] == 3) & (dataset['Education'] == 0)),'Area'] = 5
dataset.loc[((dataset['Property_Area'] == 3) & (dataset['Education'] == 1)),'Area'] = 6

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 16 columns):
# Loan_ID              480 non-null object
# Gender               480 non-null object
# Married              480 non-null object
# Dependents           480 non-null int32
# Education            480 non-null object
# Self_Employed        480 non-null object
# ApplicantIncome      480 non-null int64
# CoapplicantIncome    480 non-null float64
# LoanAmount           480 non-null float64
# Loan_Amount_Term     480 non-null float64
# Credit_History       480 non-null float64
# Property_Area        480 non-null object
# Loan_Status          480 non-null object
# Marital              480 non-null float64
# Income               480 non-null int32
# Area                 480 non-null float64
# dtypes: float64(6), int32(2), int64(1), object(7)
# memory usage: 80.0+ KB

# %%
g = sns.FacetGrid(dataset,col='Loan_Status')
g.map(plt.hist,'Area',bins=10)
plt.show()

# %%
g = sns.FacetGrid(dataset,col='Loan_Status')
g.map(plt.hist,'Credit_History',bins=10)
plt.show()

# %%
cols = ['Marital','Income','Area','Credit_History','Self_Employed']
y = dataset['Loan_Status']
X = dataset[cols]

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
# Loan_ID              367 non-null object
# Gender               356 non-null object
# Married              367 non-null object
# Dependents           357 non-null object
# Education            367 non-null object
# Self_Employed        344 non-null object
# ApplicantIncome      367 non-null int64
# CoapplicantIncome    367 non-null int64
# LoanAmount           362 non-null float64
# Loan_Amount_Term     361 non-null float64
# Credit_History       338 non-null float64
# Property_Area        367 non-null object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
dataset1 = dataset1.dropna(subset=['Gender'])
dataset1 = dataset1.dropna(subset=['Dependents'])
dataset1 = dataset1.dropna(subset=['Self_Employed'])
dataset1 = dataset1.dropna(subset=['LoanAmount'])
dataset1 = dataset1.dropna(subset=['Loan_Amount_Term'])
dataset1 = dataset1.dropna(subset=['Credit_History'])

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 289 entries, 0 to 366
# Data columns (total 12 columns):
# Loan_ID              289 non-null object
# Gender               289 non-null object
# Married              289 non-null object
# Dependents           289 non-null object
# Education            289 non-null object
# Self_Employed        289 non-null object
# ApplicantIncome      289 non-null int64
# CoapplicantIncome    289 non-null int64
# LoanAmount           289 non-null float64
# Loan_Amount_Term     289 non-null float64
# Credit_History       289 non-null float64
# Property_Area        289 non-null object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 29.4+ KB

# %%
dataset1.loc[dataset1['Gender'] == 'Male','Gender'] = 0
dataset1.loc[dataset1['Gender'] == 'Female','Gender'] = 1

dataset1.loc[dataset1['Dependents'] == '3+','Dependents'] = 4
dataset1['Dependents'] = dataset1['Dependents'].astype(int)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.27, random_state=0)

y_train = y_train.astype(int)

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

clf = DecisionTreeClassifier(criterion = "gini",random_state=100, max_depth=3, min_samples_leaf=5)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
y_pred = clf.predict(X_test)

y_test = y_test.astype(int)
accuracy_score(y_test,y_pred,normalize=True)
# Out:
# 0.79230769230769227
